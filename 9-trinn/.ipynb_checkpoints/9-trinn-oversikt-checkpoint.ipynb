# %% [markdown]
# # Programmering i 9. trinn

# %% [markdown]
# ## Læreplanmål i programmering
# * simulere utfall i tilfeldige forsøk og beregne sannsynligheten for at noe skal inntreffe, ved å bruke programmering
# ## Aktuelle læreplanmål i matematikk
# * kommer
# ## Forslag til læring
# * Dette kompetansemålet er veldig spesifikt
# * Programmering er veldig bra til aktiviteter med sannsynlighet
# * Koble analogaktiviteter (for eksempel terningkast) til å gjøre samme forsøk med programmering
# * Undersøke sammenhenger knyttet til stokastiske forsøk og store talls lov

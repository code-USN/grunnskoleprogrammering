# %% [markdown]
# # Programmering i 7. trinn

# %% [markdown]
# ## Læreplanmål i programmering
# * bruke programmering til å utforske data i tabeller og datasett
# ## Aktuelle læreplanmål i matematikk
# * kommer
# ## Forslag til læring
# * Selv om dette er mulig i for eksempel scratch så er det veldig begrenset hva man kan få til med lister og tabeller
# * Her anbefaler vi på det sterkeste å begynne med tekstprogrammering
# * Det er lettere å lage lister, behandle lister og gjøre beregninger på innhold i lister i tekstprogrammering
# * Kan kobles til kompetansemålet om sentralmål og statistikk
# * Kan kobles til sannsynlighetsregning, men det er ikke kompetansemål på 7. trinn

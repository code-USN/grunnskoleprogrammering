# %% [markdown]
# # Programmering i 8. trinn

# %% [markdown]
# ## Læreplanmål i programmering
# * utforske hvordan algoritmer kan skapes, testes og forbedres ved hjelp av programmering
# ## Aktuelle læreplanmål i matematikk
# * kommer
# ## Forslag til læring
# Dette kompetansemålet er svært åpent
# * Elevene bør løse oppgaver knyttet til feilsøking, gjerne med styrte aktiviteter i starten
# * Elevene bør lære å feilsøke sine egne og hverandres programmer
# * Programmeringsaktiviteter kan med fordel knyttes til kompetansemålene i matematikk
#     * Forsterking av variabelbegrepet, koble til algebra og formler
#     * Primtall(?)
#     * Algebraiske regneregler (programmeringssyntaks for utregninger)
#     * Beskrive mønster (koble figurtall og sekvenser til programmering
#     * Med mer!

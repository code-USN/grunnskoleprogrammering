# %% [markdown]
# # Betingelser

# %% [markdown]
# ## Logiske operatorer

# %% [markdown]
# :::{table} Oversikt over logiske operatorer i Python
# :label: table
# :align: left
# | Operator | Forklaring |
# | --- | --- |
# | == | tester for likhet |
# | \< | tester for ulikhet (mindre enn) |
# | \> |tester for ulikhet (større enn) |
# | <= | tester for ulikhet (mindre enn ELLER lik) |
# | \>= |tester for ulikhet (større enn ELLER lik) |
# | != | tester for ikke-lik |
# :::

# %% [markdown]
# ## En enkel betingelse

# %%
alder = 17
if alder < 18:
    print("Du er under 18")
# Out:
# Du er under 18

# %% [markdown]
# ## Hvis-ellers (if - else)

# %%
alder = 18
if alder < 18:
    print("Du er under 18")
else:
    print("Du er 18 eller eldre")
# Out:
# Du er 18 eller eldre

# %% [markdown]
# ## Hvis, ellers hvis, ellers

# %%
alder = 25
if alder < 18:
    print("Du er under 18")
elif alder < 67:
    print("Du er 18 eller eldre, men yngre enn 67")
else:
    print("Du er 67 eller eldre")
# Out:
# Du er 18 eller eldre, men yngre enn 67

# %% [markdown]
# ## Sammensatte betingelser

# %%
alder = 25
if alder >= 18 or alder < 67:
    print("Du er 18 eller eldre, men yngre enn 67")
# Out:
# Du er 18 eller eldre, men yngre enn 67

# %%
alder = 24
student = True
if alder < 35 and student == True:
    print("Du kan få studentrabatt")
# Out:
# Du kan få studentrabatt

# %% [markdown]
# # Kortkurs i Python

# %% [markdown]
# Her er noen korte eksempler på
# * variabler og operatorer
# * betingelser
# * løkker
# * funksjoner
# * bruk av biblioteker
# i Python.

# %% [markdown]
# Anbefaler Thonny eller Spyder

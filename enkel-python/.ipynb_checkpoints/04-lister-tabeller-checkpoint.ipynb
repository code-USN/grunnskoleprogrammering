# %% [markdown]
# # Lister og tabeller (og plotting)

# %%
navneliste = ["Åse", "Ole", "Anders", "Petter"]
navneliste.sort()
print(navneliste)
# Out:
# ['Anders', 'Ole', 'Petter', 'Åse']

# %%
data = [10, 12, 15, 9, 8, 2, 6]
antall = len(data)
sum = 0
for i in range(antall):
    sum = sum + data[i]
print(sum)
print(sum/antall)
# Out:
# 62
# 8.857142857142858

# %%
import numpy as np
x = np.linspace(-3,3,7)
y = x**2-4
print(x)
print(y)
# Out:
# [-3. -2. -1.  0.  1.  2.  3.]
# [ 5.  0. -3. -4. -3.  0.  5.]
